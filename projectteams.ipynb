# %%
[12:20 PM, 4/30/2024] Rajashekar: import numpy as np
from numpy import random as rs
Team_leaders=['soumya(Team_lead-1)','Mona(Team_lead-2)','Abhiram(Team_lead-3)','shivani(Team_lead-4)','anirudh(Team_lead-5)','sahitha(Team_lead-6)','harshini(Team_lead-7)','vathsalya(Team_lead-8)','krishna teja(Team_lead-9)','laxman(Team_lead-10)','vivek(Team_lead-11)','varshitha(Team_lead-12)','srivalli(Team_lead-13)','spandana(Team_lead-14)']
Batch_1=['Akansha','Balaram','srija','p.sumanth','Akhil','sriya','vimala','bhaskar','harshitha','D,Gayathri','J.Sahiyhya','Syed Inayath','Shiza','Rajashekar']
Batch_2=['sai tharun','shiva','sai teja','sidharth','venky','saivenkat','anusha','akash','mukesh','praharsha','manorath','surya','dileep','narender',]
Batch_3=['vishnu','gathri','A.sumath','saketh','vaishnav','nouman','raviteja','vishal','vinayak','nehal','jyotsna','sridhar','rahul','praneeth']
[3:51 PM, 4/30/2024] Rajashekar: import numpy as np
from numpy import random as rs
Team_leaders=['soumya(Team_lead-1)','Mona(Team_lead-2)','Abhiram(Team_lead-3)','shivani(Team_lead-4)','anirudh(Team_lead-5)','sahitha(Team_lead-6)','harshini(Team_lead-7)','vathsalya(Team_lead-8)','krishna teja(Team_lead-9)','laxman(Team_lead-10)','vivek(Team_lead-11)','varshitha(Team_lead-12)','srivalli(Team_lead-13)','spandana(Team_lead-14)']
Batch_1=['Akansha','Balaram','srija','p.sumanth','Akhil','sriya','vimala','bhaskar','harshitha','D,Gayathri','J.Sahiyhya','Syed Inayath','Shiza','Rajashekar']
Batch_2=['sai tharun','shiva','sai teja','sidharth','venky','saivenkat','anusha','akash','mukesh','praharsha','manorath','surya','dileep','narender',]
Batch_3=['vishnu','gathri','A.sumath','saketh','vaishnav','nouman','ravi teja','vishal','vinayak','nehal','jyotsna','sridhar','rahul','praneeth']
def batches_count():
    print("ALL BATCHES COUNT IS FOLLOWING:-")
    print("\n")
    print(" total Team leaders:-",len(Team_leaders))
    print("batch_1 total members:-",len(Batch_1))
    print("batch_2 total members:-",len(Batch_2))
    print("batch_3 total members:-",len(Batch_3))
def batch_detail():
    print("BATCHES ARE MADE ACCORDING TO CANDIDATES CGPA AND BACKLOGS")
    print("\n")
    print('TEAM-LEADERS BATCH  consist of following members:-')
    print("\n")
    for i in Team_leaders:
     print(i)
    print("\n")
    print('BATCH_1  consist of following members:-')
    print("\n")
    for i in Batch_1:
     print(i)
    print("\n")
    print('BATCH_2  consist of following members:-')
    print("\n")
    for i in Batch_2:
     print(i)
    print("\n")
    print('BATCH_3  consist of following members:-')
    print("\n")
    for i in Batch_3:
     print(i)
def making_teams():
  soumya_team=['SOUMYA(Team_lead-1)']
  mona_team=['MONA(Team_lead-1)']
  abhiram_team=['ABHIRAM(Team_lead-1)']
  shivani_team=['SHIVANI(Team_lead-1)']
  anirudh_team=['ANIRUDH(Team_lead-1)']
  sahithi_team=['SAHITHI(Team_lead-1)']
  harshini_team=['HARSHINI(Team_lead-1)']
  vathsalya_team=['VATHSALYA(Team_lead-1)']
  krishna_team=['KRISHNA TEJA(Team_lead-1)']
  laxman_team=['LAXMAN(Team_lead-1)']
  vivek_team=['VIVEK(Team_lead-1)']
  varshitha_team=['VARSHITHA(Team_lead-1)']
  srivalli_team=['SRIVALLI(Team_lead-1)']
  spandana_team=['SPANDANA(Team_lead-1)']
  Batch1copy=Batch_1
  Batch2copy=Batch_2
  Batch3copy=Batch_3
  leaders=['soumya_team','mona_team','abhiram_team','shivani_team','anirudh_team','sahithi_team','harshini_team','vathsalya_team','krishna_team','laxman_team','vivek_team','varshitha_team','srivalli_team','spandana_team']
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  soumya_team.append(a)
  soumya_team.append(b)
  soumya_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  mona_team.append(a)
  mona_team.append(b)
  mona_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  abhiram_team.append(a)
  abhiram_team.append(b)
  abhiram_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  shivani_team.append(a)
  shivani_team.append(b)
  shivani_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  anirudh_team.append(a)
  anirudh_team.append(b)
  anirudh_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  sahithi_team.append(a)
  sahithi_team.append(b)
  sahithi_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  harshini_team.append(a)
  harshini_team.append(b)
  harshini_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  vathsalya_team.append(a)
  vathsalya_team.append(b)
  vathsalya_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  krishna_team.append(a)
  krishna_team.append(b)
  krishna_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  laxman_team.append(a)
  laxman_team.append(b)
  laxman_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  vivek_team.append(a)
  vivek_team.append(b)
  vivek_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  varshitha_team.append(a)
  varshitha_team.append(b)
  varshitha_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  srivalli_team.append(a)
  srivalli_team.append(b)
  srivalli_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  a=rs.choice(Batch1copy)
  b=rs.choice(Batch2copy)
  c=rs.choice(Batch3copy)
  spandana_team.append(a)
  spandana_team.append(b)
  spandana_team.append(c)
  Batch1copy.remove(a)
  Batch2copy.remove(b)
  Batch3copy.remove(c)
  print(soumya_team)
  print(mona_team)
  print(abhiram_team)
  print(shivani_team)
  print(sahithi_team)
  print(harshini_team)
  print(vathsalya_team)
  print(krishna_team)
  print(laxman_team)
  print(vivek_team)
  print(varshitha_team)
  print(srivalli_team)
  print(spandana_team)
while(1):
  print('MENU:-'1)
  print("1.to know batches count")
  print('2.to know batches details')
  print('3.to make teams')
  choice=int(input("enter your choice"))
  if(choice==1):
    batches_count()
  elif(choice==2):
    batch_detail()
  elif(choice==3):
    making_teams()
  else:
    print("enter valid choice")
